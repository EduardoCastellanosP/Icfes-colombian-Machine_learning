# %% [markdown]
# <img src = "https://drive.google.com/uc?export=view&id=1rSrsZ04aJ_D3BC67Cy2dBUZ6tmguydNf" alt = "Encabezado MLDS" width = "100%">  </img>

# %% [markdown]
# # **Entendimiento y carga de los datos**
# ---
#
# Este notebook es una plantilla que le puede servir como guía para el tercer entregable del proyecto aplicado.

# %% [markdown]
# ## **0. Integrantes del equipo de trabajo**
# ---

# %% [markdown]
# 1. ---**Eduardo Elias Castellanos Picon CC 1068390127 <eduardoeliascastellanospicon@gmail.com>**---
# 2. ---**Anthony Joao Parra CC 1073165713 <anthonyjoaoparra@gmail.com>**---
# 3. ---**Asdrúval Zácipa Corredor CC 79139929 <azacipac@unal.edu.co>**---

# %% [markdown]
# ## **1. Análisis Exploratorio de los Datos**
# ---
#
# Describa la estructura y la naturaleza de los datos antes de comenzar con el análisis en profundidad.

# %% [markdown]
# ### **1.1. Resumen General**
# ---
#
# - ¿Cuántos documentos tiene el *dataset*?
# - ¿En qué formato están guardados los datos?
# - ¿Qué tamaño en MB tiene el conjunto?

# %% [markdown]
# ---**INGRESE SU RESPUESTA**---
# - ¿Cuántos documentos tiene el *dataset*?
#
# El dataset a analizar ha sido descargado desde la página oficial del ICFES (https://www.icfes.gov.co/web/guest/data-icfes). Corresponde a los resultados del examen Saber11 entre los años 2017 y 2023. El archivo se encuentra en formato ZIP (ResultadosSaber11_2027_2022_Fte_ICFES.zip) e incluye a su vez 13 archivos comprimidos denominados:
#
# SB11_20171.zip
# SB11_20172.zip
# SB11_20181.zip
# SB11_20182.zip
# SB11_20191.zip
# SB11_20192.zip
# SB11_20201.zip
# SB11_20202.zip
# SB11_20211.zip
# SB11_20212.zip
# SB11_20221.zip
# SB11_20222.zip
# SB11_20231.zip
#
# - ¿En qué formato están guardados los datos?
#
# Internamente cada ZIP incluye un archivo de texto denominado SB11_YYYY[12].TXT, con encabezados y campos separados por TAB. El archivo ZIP inicial se descomprime en una carpeta con el mismo nombre que es la que será procesada.
#
# - ¿Qué tamaño en MB tiene el conjunto?
#
# El tamaño total del archivo a procesar es de 362MB
#
# El siguiente código es el utilizado para realizar la lectura y extracción de los datos del archivo ZIP y el cargue al dataframe de trabajo. En primera instancia se cargan las librerias necesarias.

# %%
import pandas as pd
import zipfile
import os
import copy
import warnings
from pathlib import Path
from IPython.display import display

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
warnings.filterwarnings("ignore") # suprimir mensajes warning
path_i = "./data/input/ResultadosSaber11_2027_2022_Fte_ICFES/" # variable que indica el nombre del archivo ZIP contenedor

# %%
def read_zip_file(filename):
    """"
    Función read_zip_file: Realiza la extracción de los datos de cada archivo zip y devuelve un dataframe por cada uno de los archivos TXT

    Parámetros:
        filanema(string): Nombre del archivo a analizar incluyendo la ruta de ubicación del mismo

    Return:
        df   (dataframe): Dataframe con los datos del archivo procesado

    Ejemplo:

        >>> df = read_zip_file(filename = './data/input/ResultadosSaber11_2027_2022_Fte_ICFES/SB11_20171.zip')

            *** processing filename ./data/input/ResultadosSaber11_2027_2022_Fte_ICFES/SB11_20171.zip
              zipfile SB11_20171.TXT
    """
    print("*** processing filename", filename)
    with zipfile.ZipFile(filename) as z:
        file = z.namelist()[0]
        print("  zipfile",file)
        with z.open(file) as f:
            df = pd.read_csv(f, header=0, delimiter="¬")
    return df

# %%
# en este segmento de codigo se procesa el archivo zip y se extraen los diferentes archivos TXT a diccionario de dataframes
obj = os.walk(path_i)
ind = 1
dict_of_df = {}
frames = []
print("*** searching files")
for root, dirs, files in obj: # Procesar todos los archivos que se encuentran en el directorio
    for entry in files:
        if (entry.endswith(".zip")):
            file_i = path_i + entry
            print("archivo", file_i)
            key_name = 'df_' + Path(os.path.basename(file_i)).stem
            frames.append(Path(os.path.basename(file_i)).stem)
            df = read_zip_file(filename = file_i)
            # se cargan los dataframes en un diccionario cuya clave es el nombre que se le da al dataframe
            dict_of_df[key_name] = copy.deepcopy(df)
print("done")
# Out:
# *** searching files
# archivo ./data/input/ResultadosSaber11_2027_2022_Fte_ICFES/SB11_20171.zip
# *** processing filename ./data/input/ResultadosSaber11_2027_2022_Fte_ICFES/SB11_20171.zip
#   zipfile SB11_20171.TXT
# archivo ./data/input/ResultadosSaber11_2027_2022_Fte_ICFES/SB11_20172.zip
# *** processing filename ./data/input/ResultadosSaber11_2027_2022_Fte_ICFES/SB11_20172.zip
#   zipfile SB11_20172.TXT
# archivo ./data/input/ResultadosSaber11_2027_2022_Fte_ICFES/SB11_20181.zip
# *** processing filename ./data/input/ResultadosSaber11_2027_2022_Fte_ICFES/SB11_20181.zip
#   zipfile SB11_20181.TXT
# archivo ./data/input/ResultadosSaber11_2027_2022_Fte_ICFES/SB11_20182.zip
# *** processing filename ./data/input/ResultadosSaber11_2027_2022_Fte_ICFES/SB11_20182.zip
#   zipfile SB11_20182.TXT
# archivo ./data/input/ResultadosSaber11_2027_2022_Fte_ICFES/SB11_20191.zip
# *** processing filename ./data/input/ResultadosSaber11_2027_2022_Fte_ICFES/SB11_20191.zip
# ...

# %% [markdown]
# ### **1.2. Exploración Preliminar**
# ---
# - ¿Cuál es la naturaleza de los datos que se van a analizar en el proyecto?
# - ¿Qué tipos de variables y características están presentes en el conjunto de datos?

# %% [markdown]
# ---**INGRESE SU RESPUESTA**---
#
# - ¿Cuál es la naturaleza de los datos que se van a analizar en el proyecto?
#
# Al revisar los dataframes generados, encontramos que en cada uno de los datasets se encuentran datos de tipo numerico y carácter que corresponden a características de la prueba Saber11 presentada por el estudiante. Los datos se pueden clasificar en los siguientes grupos:
#
# -- Datos cuantitativos: Corresponden a los resultados de la prueba Saber11 en sus diferentes asignaturas. Se reportan los siguientes:
#
# PUNT_LECTURA_CRITICA: Númerico con valor entre 1 y 100
#
# PERCENTIL_LECTURA_CRITICA: Númerico correspondiente al percentil en el que se encuentra el puntaje del estudiante en esta prueba
#
# DESEMP_LECTURA_CRITICA: Númerico de 4 niveles correspondiente a los siguientes rangos: Nivel 1 [0, 35], Nivel 2 [36, 50], Nivel 3 [51, 65], Nivel 4 [66, 100]
#
# PUNT_MATEMATICAS: Númerico con valor entre 1 y 100
#
# PERCENTIL_MATEMATICAS: Númerico correspondiente al percentil en el que se encuentra el puntaje del estudiante en esta prueba
#
# DESEMP_MATEMATICAS: Númerico de 4 niveles correspondiente a los siguientes rangos: Nivel 1 [0, 35], Nivel 2 [36, 50], Nivel 3 [51, 70], Nivel 4 [71, 100]
#
# PUNT_C_NATURALES: Númerico con valor entre 1 y 100
#
# PERCENTIL_C_NATURALES: Númerico correspondiente al percentil en el que se encuentra el puntaje del estudiante en esta prueba
#
# DESEMP_C_NATURALES: Númerico de 4 niveles correspondiente a los siguientes rangos: Nivel 1 [0, 40], Nivel 2 [41, 55], Nivel 3 [56, 70], Nivel 4 [71, 100]
#
# PUNT_SOCIALES_CIUDADANAS: Númerico con valor entre 1 y 100
#
# PERCENTIL_SOCIALES_CIUDADANAS: Númerico correspondiente al percentil en el que se encuentra el puntaje del estudiante en esta prueba
#
# DESEMP_SOCIALES_CIUDADANAS: Númerico de 4 niveles correspondiente a los siguientes rangos: Nivel 1 [0, 40], Nivel 2 [41, 55], Nivel 3 [56, 70], Nivel 4 [71, 100]
#
# PUNT_INGLES: Númerico con valor entre 1 y 100. El valor -1 indica que el estudiante no contesto las preguntas de ésta prueba
#
# PERCENTIL_INGLES: Númerico correspondiente al percentil en el que se encuentra el puntaje del estudiante en esta prueba
#
# DESEMP_INGLES: Caractér de 4 niveles correspondiente a los siguientes rangos: PreA1 [0, 36], A1 [37, 57], A2 [58, 70], B1 [71, 100]
#
# PUNT_GLOBAL: Númerico con valor entre 1 y 500
#
# PERCENTIL_GLOBAL: Númerico correspondiente al percentil en el que se encuentra el puntaje del estudiante respecto al puntaje global de la prueba

# %% [markdown]
# -- Variables que dan información del estudiante:
#
# ESTU_TIPODOCUMENTO: Tipo de documento del estudiante
#
# ESTU_NACIONALIDAD: Nacionalidad del estudiante
#
# ESTU_GENERO: Género del estudiante
#
# ESTU_FECHANACIMIENTO: Fecha de nacimiento del estudiante
#
# PERIODO: Período de presentacion de la prueba Saber11
#
# ESTU_CONSECUTIVO: Identificador único de la prueba presentada por el estudiante
#
# ESTU_ESTUDIANTE: Valor constante ESTUDIANTE
#
# ESTU_PAIS_RESIDE: Nombre del país de residencia del estudiante
#
# ESTU_TIENEETNIA: Respuesta a la pregunta ¿Pertenece usted a un grupo étnico minoritario?
#
# ESTU_ETNIA: Descripción de la etnia indicada
#
# ESTU_DEPTO_RESIDE: Nombre del departamento de residencia
#
# ESTU_COD_RESIDE_DEPTO: Código del departamento de residencia
#
# ESTU_MCPIO_RESIDE: Nombre del municipio de residencia
#
# ESTU_COD_RESIDE_MCPIO: Código del municipio de residencia
#
# ESTU_DEDICACIONLECTURADIARIA: Respuesta a la pregunta Usualmente, ¿cuánto tiempo al día dedica a leer por entretenimiento?
#
# ESTU_DEDICACIONINTERNET: Respuesta a la pregunta Usualmente, ¿cuánto tiempo al día dedica a navegar en internet? Excluya actividades académicas
#
# ESTU_HORASSEMANATRABAJA: Respuesta a la pregunta ¿Cuántas horas trabajó usted durante la semana pasada?
#
# ESTU_TIPOREMUNERACION: Tipo de remuneracion si en la anterior variable se indico un valor mayor a 0
#
# ESTU_PRIVADO_LIBERTAD: Indica si la persona que presento la prueba esta privada de la libertad.
#
# ESTU_COD_MCPIO_PRESENTACION: Código de municipio de presentación de la prueba
#
# ESTU_MCPIO_PRESENTACION: Nombre de municipio de presentación de la prueba
#
# ESTU_DEPTO_PRESENTACION: Nombre departamento de presentación de la prueba
#
# ESTU_COD_DEPTO_PRESENTACION: Código de departamento de presentación de la prueba
#
# ESTU_INSE_INDIVIDUAL: Indice socioeconómico del estudiante
#
# ESTU_NSE_INDIVIDUAL: Nivel socioeconómico a nivel del estudiante
#
# ESTU_NSE_ESTABLECIMIENTO: Nivel socioeconómico de la institucion educativa de secundaria
#
# ESTU_ESTADOINVESTIGACION: Identifica los usuarios que están en proceso de investigación en el ICFES

# %% [markdown]
# -- Variables que dan información del entorno familiar:
#
# FAMI_EDUCACIONPADRE: Nivel educativo más alto alcanzado por el padre
#
# FAMI_EDUCACIONMADRE: Nivel educativo más alto alcanzado por la madre
#
# FAMI_ESTRATOVIVIENDA: Estrato socioeconómico de la vivienda según recibo de energía eléctrica
#
# FAMI_PERSONASHOGAR: Respuesta a la pregunta ¿Cuántas personas conforman el hogar donde vive actualmente, incluido usted?
#
# FAMI_CUARTOSHOGAR: Respuesta a la pregunta En total, ¿en cuántos cuartos duermen las personas de su hogar?
#
# FAMI_TIENEINTERNET: Respuesta a la pregunta ¿Su hogar cuenta con servicio o conexión a internet?
#
# FAMI_TIENECOMPUTADOR: Respuesta a la pregunta ¿Cuáles de los siguientes bienes posee su hogar?: Computador
#
# FAMI_TIENELAVADORA: Respuesta a la pregunta ¿Cuáles de los siguientes bienes posee su hogar?: Lavadora
#
# FAMI_TIENEHORNOMICROOGAS: Respuesta a la pregunta ¿Cuáles de los siguientes bienes posee su hogar?: Horno Microondas
#
# FAMI_TIENESERVICIOTV: Respuesta a la pregunta ¿Su hogar cuenta con servicio cerrado de televisión?
#
# FAMI_TIENEAUTOMOVIL: Respuesta a la pregunta ¿Cuáles de los siguientes bienes posee su hogar?: Automóvil particular
#
# FAMI_TIENEMOTOCICLETA: Respuesta a la pregunta ¿Cuáles de los siguientes bienes posee su hogar?: Motocicleta
#
# FAMI_TIENECONSOLAVIDEOJUEGOS: Respuesta a la pregunta ¿Cuáles de los siguientes bienes posee su hogar?: Consola para juegos electrónicos (PlayStation, Xbox, Nintendo, etc.)
#
# FAMI_NUMLIBROS: Respuesta a la pregunta ¿Cuántos libros físicos o electrónicos hay en su hogar excluyendo periódicos, revistas, directorios telefónicos y libros del colegio?
#
# FAMI_COMELECHEDERIVADOS: Respuesta a la pregunta ¿Cuántas veces por semana se comen los siguientes alimentos en su hogar? Leche y/o sus derivados
#
# FAMI_COMECARNEPESCADOHUEVO: Respuesta a la pregunta ¿Cuántas veces por semana se comen los siguientes alimentos en su hogar? Carne (pollo, pavo, res, cordero, cerdo, conejo, etc.), pescados o huevos
#
# FAMI_COMECEREALFRUTOSLEGUMBRE: Respuesta a la pregunta ¿Cuántas veces por semana se comen los siguientes alimentos en su hogar? Cereal, frutas, legumbres
#
# FAMI_TRABAJOLABORPADRE: Dedicación laboral del padre
#
# FAMI_TRABAJOLABORMADRE: Dedicación laboral de la madre
#
# FAMI_SITUACIONECONOMICA: Respuesta a la pregunta Con respecto al año inmediatamente anterior, la situación económica de su hogar es: Peor, Igual, Mejor

# %% [markdown]
# -- Variables que dan información del entorno escolar:
#
# COLE_CODIGO_ICFES: Código ICFES del establecimiento educativo
#
# COLE_COD_DANE_ESTABLECIMIENTO: Código DANE del establecimiento educativo
#
# COLE_NOMBRE_ESTABLECIMIENTO: Nombre del establecimiento educativo
#
# COLE_GENERO: Indica si es femenino, masculino o mixto
#
# COLE_NATURALEZA: Indica si es oficial o privado
#
# COLE_CALENDARIO: Indica el calendario académico
#
# COLE_BILINGUE: Indica si es bilingue o no
#
# COLE_CARACTER: Indica si es académico, técnico, etc.
#
# COLE_COD_DANE_SEDE: Código DANE de la sede
#
# COLE_NOMBRE_SEDE: Nombre de la sede
#
# COLE_SEDE_PRINCIPAL: Indica si es la sede principal del establecimiento educativo
#
# COLE_AREA_UBICACION: Indica si es urbano o rural
#
# COLE_JORNADA: Jornada de la sede
#
# COLE_COD_MCPIO_UBICACION: Código del municipio de ubicación
#
# COLE_MCPIO_UBICACION: Nombre del municipio de ubicación
#
# COLE_COD_DEPTO_UBICACION: Codigo del departamento de ubicación
#
# COLE_DEPTO_UBICACION: Nombre del departamento de ubicación

# %% [markdown]
# - ¿Qué tipos de variables y características están presentes en el conjunto de datos?
#
# Todas las variables son de tipo numérico o caracter

# %% [markdown]
# ## **2. Análisis Descriptivo de los Datos**
# ---
#
# Profundice en el análisis de los datos, proporcionando una descripción detallada y estadísticas clave.

# %% [markdown]
# ### **2.1. Relaciones entre variables**
# ---
#
# - ¿Se identifican patrones, tendencias o características notables?
#
# - ¿Cómo se exploran y describen las relaciones entre variables?

# %% [markdown]
# ---**INGRESE SU RESPUESTA**---
#
# - ¿Se identifican patrones, tendencias o características notables?
#
# Una primera exploración nos permite identificar los diferentes valores de las variables del dataset. En términos generales, todos los datasets tienen las mismas columnas, las cuales tienen valores literales y numéricos.
#
# Las columnas con valores cuantitativos utilizaremos para efectos de estadísticas corresponden a las siguientes:
#
# * PUNT_LECTURA_CRITICA: Númerico con valor entre 1 y 100
# * PUNT_MATEMATICAS: Númerico con valor entre 1 y 100
# * PUNT_C_NATURALES: Númerico con valor entre 1 y 100
# * PUNT_SOCIALES_CIUDADANAS: Númerico con valor entre 1 y 100
# * PUNT_INGLES: Númerico con valor entre 1 y 100. El valor -1 indica que el estudiante no contesto las preguntas de ésta prueba
# * PUNT_GLOBAL: Númerico con valor entre 1 y 500

# %% [markdown]
# Otras características importantes a considerar son:
#
# * ESTU_GENERO
# * ESTU_DEPTO_RESIDE
# * ESTU_COD_RESIDE_DEPTO
# * ESTU_DEDICACIONLECTURADIARIA
# * ESTU_DEDICACIONINTERNET
# * ESTU_HORASSEMANATRABAJA
#
# * FAMI_EDUCACIONPADRE
# * FAMI_EDUCACIONMADRE
# * FAMI_ESTRATOVIVIENDA
# * FAMI_PERSONASHOGAR
# * FAMI_CUARTOSHOGAR
# * FAMI_TIENEINTERNET
# * FAMI_TIENECOMPUTADOR
# * FAMI_TIENELAVADORA
# * FAMI_TIENEHORNOMICROOGAS
# * FAMI_TIENESERVICIOTV
# * FAMI_TIENEAUTOMOVIL
# * FAMI_TIENEMOTOCICLETA
# * FAMI_TIENECONSOLAVIDEOJUEGOS
# * FAMI_NUMLIBROS
# * FAMI_COMELECHEDERIVADOS
# * FAMI_COMECARNEPESCADOHUEVO
# * FAMI_COMECEREALFRUTOSLEGUMBRE
# * FAMI_TRABAJOLABORPADRE
# * FAMI_TRABAJOLABORMADRE
# * FAMI_SITUACIONECONOMICA
#
# * COLE_CODIGO_ICFES
# * COLE_COD_DANE_ESTABLECIMIENTO
# * COLE_NOMBRE_ESTABLECIMIENTO
# * COLE_GENERO
# * COLE_NATURALEZA
# * COLE_CALENDARIO
# * COLE_BILINGUE
# * COLE_CARACTER
# * COLE_COD_DANE_SEDE
# * COLE_NOMBRE_SEDE
# * COLE_SEDE_PRINCIPAL
# * COLE_AREA_UBICACION
# * COLE_JORNADA
# * COLE_COD_MCPIO_UBICACION
# * COLE_MCPIO_UBICACION
# * COLE_COD_DEPTO_UBICACION
# * COLE_DEPTO_UBICACION

# %%
# validar los dataframes antes de concatenar
columnList = []
dictDf     = {}
for name_df in list(dict_of_df.keys()):
    print("\ndf",name_df)
    df = dict_of_df[name_df]
    display(df.head(5))
    columnList.append(df.columns)
    key_name = name_df
    dictDf[key_name] = df.columns
print("done")
# Out:
# df df_SB11_20171
#   ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO ESTU_FECHANACIMIENTO  \
# 0                 TI          COLOMBIA           M           19/06/2000
# 1                 TI          COLOMBIA           F           02/09/2000
# 2                 TI          COLOMBIA           F           25/05/2000
# 3                 TI          COLOMBIA           M           08/02/1999
# 4                 TI          COLOMBIA           F           20/08/1999
#
#    PERIODO  ESTU_CONSECUTIVO ESTU_ESTUDIANTE ESTU_PAIS_RESIDE ESTU_TIENEETNIA  \
# 0    20171  SB11201710005624      ESTUDIANTE         COLOMBIA              No
# 1    20171  SB11201710008394      ESTUDIANTE         COLOMBIA              No
# 2    20171  SB11201710015727      ESTUDIANTE         COLOMBIA              No
# 3    20171  SB11201710020106      ESTUDIANTE         COLOMBIA              No
# 4    20171  SB11201710014735      ESTUDIANTE         COLOMBIA              No
#
# ...

# %% [markdown]
# -- ¿Cómo se exploran y describen las relaciones entre variables?
#
# De la exploración de los datos, se identifica el campo ESTU_CONSECUTIVO que corresponde al identificador asignado al estudiante para la presentación de la prueba Saber11. Este campo será de utilizar para indexar las colecciones a generar.
#
# Las variables cuantitativas correspondientes al puntajo obtenido en las pruebas, segun lo identificado en el proyecto de Machine Learning tienen relación con las siguientes variables, en donde se identificó alguna medida de correlación y por lo tanto fueron variables a considerar en el modelo de clasificación desarrollado. Estas variables corresponden a las siguientes:
#
# * FAMI_EDUCACIONMADRE
# * FAMI_EDUCACIONPADRE
# * FAMI_ESTRATOVIVIENDA
# * ESTU_DEDICACIONLECTURADIARIA
# * FAMI_NUMLIBROS
# * ESTU_DEDICACIONINTERNET
# * FAMI_COMELECHEDERIVADOS
# * ESTU_EDAD
# * FAMI_COMECARNEPESCADOHUEVO
# * FAMI_SITUACIONECONOMICA
# * COLE_JORNADA
# * FAMI_TIENECOMPUTADOR
# * FAMI_TIENEINTERNET
# * COLE_NATURALEZA
# * ESTU_GENERO
# * COLE_CARACTER
# * COLE_CALENDARIO
#
# En donde la variable ESTU_EDAD corresponde a una variable calculada en función de la fecha de nacimiento del estudiante y la fecha de presentación de la prueba. Esta variable no se tendra en cuenta inicialmente.

# %%
# validar los dataframes antes de concatenar
columnList = []
dictDf     = {}
for name_df in list(dict_of_df.keys()):
    print("\ndf",name_df)
    df = dict_of_df[name_df]
    display(df.describe())
print("done")
# Out:
# df df_SB11_20171
#        PERIODO  ESTU_COD_RESIDE_DEPTO  ESTU_COD_RESIDE_MCPIO  \
# count  12993.0           12993.000000           12993.000000
# mean   20171.0              48.132995           48189.418071
# std        0.0              31.137969           31159.397700
# min    20171.0               5.000000            5001.000000
# 25%    20171.0              11.000000           11001.000000
# 50%    20171.0              76.000000           76001.000000
# 75%    20171.0              76.000000           76001.000000
# max    20171.0              91.000000           91001.000000
#
#        COLE_CODIGO_ICFES  COLE_COD_DANE_ESTABLECIMIENTO  COLE_COD_DANE_SEDE  \
# count       12993.000000                   1.299300e+04        1.299300e+04
# mean        61073.115447                   3.573368e+11        3.573368e+11
# std         60902.468801                   4.112046e+10        4.112046e+10
# min           182.000000                   1.765200e+11        1.765200e+11
# ...

# %% [markdown]
# Se observa en las anteriores estadísticas que hay variables numéricas en el dataset que realmente corresponden a códigos (Ej. ESTU_COD_RESIDE_DEPTO, COLE_CODIGO_ICFES), las cuales no brindan información a nivel estadístico, pero nos podrán ser de utilidad para efectos de variables de agrupación para generacion de estadísticas sobre las variables correspondientes al resultado obtenidos en las pruebas.

# %% [markdown]
# ## **3. Carga o Adquisición de Datos**
# ---
#
# Agregue el código necesario en _Python_ para obtener o cargar los datos.

# %% [markdown]
# ### **3.1. Origen de los datos**
# ---
# - ¿Cuál es la fuente principal de los datos?
#
# Como se ha mencionado, el dataset a analizar ha sido descargado desde la página oficial del ICFES (https://www.icfes.gov.co/web/guest/data-icfes). Corresponde a los resultados del examen Saber11 entre los años 2017 y 2023.
#
# - ¿Existen consideraciones especiales al extraer datos de esta fuente?
#
# No se tienen consideraciones especiales para la extracción de los datos de la fuente

# %% [markdown]
# - ¿Cómo se obtienen los datos del origen a la plataforma de Big Data?
#
# Para efectos de la definicion de la arquitectura de soporte de los datos para Big Data, se utilizará la base de datos orientada a documentos MongoDB.
#
# Al revisar los datos, no todos se aprecian de interés para el proyecto. Para los considerados, se organizaron en colecciones de la siguiente forma:
#
# -- Colección icfes_estudiante_estudiante:
#
# <img src="https://drive.google.com/uc?export=view&id=111wmkhAf4CLo0K7m7KDrpB_JXj_H1aa1" width="50%">
#
# -- Colección icfes_estudiante_colegio:
#
# <img src="https://drive.google.com/uc?export=view&id=1HnhBxQPhiFTVcSpXRH0RRMvU0cK6H5Nw" width="50%">
#
# -- Colección icfes_estudiante_familia:
#
# <img src="https://drive.google.com/uc?export=view&id=1MzyS3ziH1qm04TSr_2cUIjQLkAAOgylF" width="70%">

# %% [markdown]
# Para facilitar la generación de estadísticas, los datos correspondientes al puntaje en las diferentes pruebas se incluye como un nodo anidado en cada uno de los tipos de datos.

# %% [markdown]
# - ¿Se utilizan herramientas específicas?
#
# Se utilizan las librerias pymongo y pymongoarrow con el fin de realizar el cargue de los datos en la base de datos

# %% [markdown]
# A continuación se incluye el código mediante el cual se crearan las colecciones según la estructura presentada en el numeral anterior y se procedera a realizar el cargue de los documentos correspondientes.

# %%
# INGRESE SU CÓDIGO
from pymongo import MongoClient
import json

# %%
# definir la conexion al servidor de la base de datos
connection_str = "mongodb://localhost:27017/"
client = MongoClient(connection_str)

# %%
# definir la base de datos a trabajar
db = client["icfes_db_mlds"]
print(db)
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'icfes_db_mlds')

# %%
def create_collection(collection, db):
    """"
    Función create_collection: Permite borrar y crear una colección en la base de datos

    Parámetros:
        collection   (string): Nombre de la colección a crear. Si existe previamente es borrada previo a la creación
        df (Database MongoDB): Identificador de la base de datos

    Return:
        collection (Collection MongoDB): Identificador de la colección creada en la base de datos

    Ejemplo:

        >>> icfes_estudiante_resultado  = create_collection("icfes_estudiante_resultado", db)

            *** creating collection icfes_estudiante_resultado
            done
    """
    print("*** creating collection", collection)
    db.drop_collection(collection)
    collection = db[collection]
    print("done")
    return collection

# %%
def load_collection(df, collection, columns, db):
    """"
    Función load_collection: Realiza la inserción de documentos en la colección que se indica a partir de un DataFrame Pandas

    Parámetros:
        df                  (Dataframe): Nombre del Dataframe con los datos a insertar como documentos en la colección
        collection (Collection MongoDB): Nombre de la colección sobre la cual se realizará la carga de los documentos
        columns                  (List): Lista de columnas a extraer del dataframe de entrada para generar los documentos a cargar en la colección
        db           (Database MongoDB): Identificador de la base de datos

    Return:
        None

    Ejemplo:

        >>> load_collection(dict_of_df[name_df], icfes_estudiante_resultado, columns, db)

            *** loading collection Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'icfes_db_mlds')
            , 'icfes_estudiante_resultado')
            done
    """
    print("*** loading collection", collection)
    df_tmp = df[columns]
    df_tmp.reset_index(inplace=True)
    data_dict = df_tmp.to_dict("records")
    collection.insert_many(data_dict)
    print("done")
    return None

# %%
def prepare_list(keys_cols, keys, keys_target, df, nested_node_name):
    """"
    Función prepare_list: Prepara lista de documentos para insertarlos en la base de datos

    Parámetros:
        keys_cols          (List): Lista de atributos a generar en el documento
        keys               (List): Lista de atributos a generar en el nodo principal del documento
        keys_target        (List): Lista de atributos a generar en el nodo anidado del documento
        df            (Dataframe): Dataframe con los datos
        nested_node_name (String): Nombre del nodo donde se depositaran los atributos anidados

    Return:
        mylist             (List): Lista de documentos a insertar en la colección

    Ejemplo:

        >>> mylist = prepare_list(keys_cols = keys_cols, keys = keys, keys_target = keys_target, df = dict_of_df[name_df], nested_node_name = 'PUNTAJE')
    """
    mydict = {}
    len_keys_cols = len(keys_cols) + 1
    for row in df[keys_cols].itertuples(index=False):
        for i in range(len(keys),len(keys_cols)):
            mydict.setdefault(row[:len_keys_cols], {})[keys_cols[i]] = row[i]

    mylist = [{**dict(zip(keys, k)), nested_node_name: v} for k, v in mydict.items()]
    return mylist

# %%
icfes_estudiante_familia    = create_collection("icfes_estudiante_familia", db)
icfes_estudiante_estudiante = create_collection("icfes_estudiante_estudiante", db)
icfes_estudiante_colegio    = create_collection("icfes_estudiante_colegio", db)
# Out:
# *** creating collection icfes_estudiante_familia
# done
# *** creating collection icfes_estudiante_estudiante
# done
# *** creating collection icfes_estudiante_colegio
# done

# %%
# procesar los dataframes
ind = 1
for name_df in list(dict_of_df.keys()):
    #
    print("**** processing dataframe",name_df)
    #
    keys_cols = ['ESTU_CONSECUTIVO','FAMI_EDUCACIONPADRE','FAMI_EDUCACIONMADRE','FAMI_ESTRATOVIVIENDA','FAMI_PERSONASHOGAR','FAMI_CUARTOSHOGAR'
           ,'FAMI_TIENEINTERNET','FAMI_TIENECOMPUTADOR','FAMI_TIENELAVADORA','FAMI_TIENEHORNOMICROOGAS','FAMI_TIENESERVICIOTV'
           ,'FAMI_TIENEAUTOMOVIL','FAMI_TIENEMOTOCICLETA','FAMI_TIENECONSOLAVIDEOJUEGOS','FAMI_NUMLIBROS','FAMI_COMELECHEDERIVADOS'
           ,'FAMI_COMECARNEPESCADOHUEVO','FAMI_COMECEREALFRUTOSLEGUMBRE','FAMI_TRABAJOLABORPADRE','FAMI_TRABAJOLABORMADRE'
           ,'FAMI_SITUACIONECONOMICA'
           ,'PUNT_LECTURA_CRITICA','PUNT_MATEMATICAS'
           ,'PUNT_C_NATURALES','PUNT_SOCIALES_CIUDADANAS','PUNT_INGLES','PUNT_GLOBAL']
    keys = ['ESTU_CONSECUTIVO','FAMI_EDUCACIONPADRE','FAMI_EDUCACIONMADRE','FAMI_ESTRATOVIVIENDA','FAMI_PERSONASHOGAR','FAMI_CUARTOSHOGAR'
           ,'FAMI_TIENEINTERNET','FAMI_TIENECOMPUTADOR','FAMI_TIENELAVADORA','FAMI_TIENEHORNOMICROOGAS','FAMI_TIENESERVICIOTV'
           ,'FAMI_TIENEAUTOMOVIL','FAMI_TIENEMOTOCICLETA','FAMI_TIENECONSOLAVIDEOJUEGOS','FAMI_NUMLIBROS','FAMI_COMELECHEDERIVADOS'
           ,'FAMI_COMECARNEPESCADOHUEVO','FAMI_COMECEREALFRUTOSLEGUMBRE','FAMI_TRABAJOLABORPADRE','FAMI_TRABAJOLABORMADRE'
           ,'FAMI_SITUACIONECONOMICA']
    keys_target = ['PUNT_LECTURA_CRITICA','PUNT_MATEMATICAS','PUNT_C_NATURALES','PUNT_SOCIALES_CIUDADANAS','PUNT_INGLES','PUNT_GLOBAL']
    #
    mylist = prepare_list(keys_cols = keys_cols, keys = keys, keys_target = keys_target, df = dict_of_df[name_df], nested_node_name = 'PUNTAJE')
    icfes_estudiante_familia.insert_many(mylist)
    #
    keys_cols = ['ESTU_CONSECUTIVO','ESTU_TIPODOCUMENTO','ESTU_NACIONALIDAD','ESTU_GENERO','ESTU_FECHANACIMIENTO','PERIODO','ESTU_PAIS_RESIDE'
           ,'ESTU_TIENEETNIA','ESTU_DEPTO_RESIDE','ESTU_COD_RESIDE_DEPTO','ESTU_MCPIO_RESIDE','ESTU_COD_RESIDE_MCPIO'
           ,'ESTU_DEDICACIONLECTURADIARIA','ESTU_DEDICACIONINTERNET','ESTU_HORASSEMANATRABAJA','ESTU_TIPOREMUNERACION','ESTU_PRIVADO_LIBERTAD'
           ,'ESTU_COD_MCPIO_PRESENTACION','ESTU_MCPIO_PRESENTACION','ESTU_DEPTO_PRESENTACION','ESTU_COD_DEPTO_PRESENTACION'
           ,'PUNT_LECTURA_CRITICA','PUNT_MATEMATICAS'
           ,'PUNT_C_NATURALES','PUNT_SOCIALES_CIUDADANAS','PUNT_INGLES','PUNT_GLOBAL']
    keys = ['ESTU_CONSECUTIVO','ESTU_TIPODOCUMENTO','ESTU_NACIONALIDAD','ESTU_GENERO','ESTU_FECHANACIMIENTO','PERIODO','ESTU_PAIS_RESIDE'
           ,'ESTU_TIENEETNIA','ESTU_DEPTO_RESIDE','ESTU_COD_RESIDE_DEPTO','ESTU_MCPIO_RESIDE','ESTU_COD_RESIDE_MCPIO'
           ,'ESTU_DEDICACIONLECTURADIARIA','ESTU_DEDICACIONINTERNET','ESTU_HORASSEMANATRABAJA','ESTU_TIPOREMUNERACION','ESTU_PRIVADO_LIBERTAD'
           ,'ESTU_COD_MCPIO_PRESENTACION','ESTU_MCPIO_PRESENTACION','ESTU_DEPTO_PRESENTACION','ESTU_COD_DEPTO_PRESENTACION']
    keys_target = ['PUNT_LECTURA_CRITICA','PUNT_MATEMATICAS','PUNT_C_NATURALES','PUNT_SOCIALES_CIUDADANAS','PUNT_INGLES','PUNT_GLOBAL']
    #
    mylist = prepare_list(keys_cols = keys_cols, keys = keys, keys_target = keys_target, df = dict_of_df[name_df], nested_node_name = 'PUNTAJE')
    icfes_estudiante_estudiante.insert_many(mylist)
    #
    keys_cols = ['ESTU_CONSECUTIVO','COLE_CODIGO_ICFES','COLE_COD_DANE_ESTABLECIMIENTO','COLE_NOMBRE_ESTABLECIMIENTO','COLE_GENERO'
           ,'COLE_NATURALEZA','COLE_CALENDARIO','COLE_BILINGUE','COLE_CARACTER','COLE_COD_DANE_SEDE','COLE_NOMBRE_SEDE'
           ,'COLE_SEDE_PRINCIPAL','COLE_AREA_UBICACION','COLE_JORNADA','COLE_COD_MCPIO_UBICACION','COLE_MCPIO_UBICACION'
           ,'COLE_COD_DEPTO_UBICACION','COLE_DEPTO_UBICACION'
           ,'PUNT_LECTURA_CRITICA','PUNT_MATEMATICAS'
           ,'PUNT_C_NATURALES','PUNT_SOCIALES_CIUDADANAS','PUNT_INGLES','PUNT_GLOBAL']
    keys = ['ESTU_CONSECUTIVO','COLE_CODIGO_ICFES','COLE_COD_DANE_ESTABLECIMIENTO','COLE_NOMBRE_ESTABLECIMIENTO','COLE_GENERO'
           ,'COLE_NATURALEZA','COLE_CALENDARIO','COLE_BILINGUE','COLE_CARACTER','COLE_COD_DANE_SEDE','COLE_NOMBRE_SEDE'
           ,'COLE_SEDE_PRINCIPAL','COLE_AREA_UBICACION','COLE_JORNADA','COLE_COD_MCPIO_UBICACION','COLE_MCPIO_UBICACION'
           ,'COLE_COD_DEPTO_UBICACION','COLE_DEPTO_UBICACION']
    keys_target = ['PUNT_LECTURA_CRITICA','PUNT_MATEMATICAS','PUNT_C_NATURALES','PUNT_SOCIALES_CIUDADANAS','PUNT_INGLES','PUNT_GLOBAL']
    #
    mylist = prepare_list(keys_cols = keys_cols, keys = keys, keys_target = keys_target, df = dict_of_df[name_df], nested_node_name = 'PUNTAJE')
    icfes_estudiante_colegio.insert_many(mylist)
    #
print("done")
# Out:
# **** processing dataframe df_SB11_20171
# **** processing dataframe df_SB11_20172
# **** processing dataframe df_SB11_20181
# **** processing dataframe df_SB11_20182
# **** processing dataframe df_SB11_20191
# **** processing dataframe df_SB11_20192
# **** processing dataframe df_SB11_20201
# **** processing dataframe df_SB11_20202
# **** processing dataframe df_SB11_20211
# **** processing dataframe df_SB11_20212
# **** processing dataframe df_SB11_20221
# **** processing dataframe df_SB11_20222
# **** processing dataframe df_SB11_20231
# done

# %% [markdown]
# Como complemento a los datos, realizaremos la creación de una colección correspondiente a la relación de instituciones educativas de la ciudad de Bogotá. Esta colección nos permitirá conocer la distribución de los puntajes de la prueba Saber11 en las diferentes localidades de la ciudad. La estructura de esta colección será:
#
# -- Colección colegios_localidad_bogota:
#
# <img src="https://drive.google.com/uc?export=view&id=1OCKraSc1bzxPUkaFNXrmqrRbOhaH9_BJ" width="50%">

# %%
# Cargar dataframe con los datos de colegios por localidad en Bogotá
path_i = "./data/input/"
file_i = "colegios_bogota_localidad.csv"
df_colegios_bogota = pd.read_csv(path_i + file_i)

# %%
# estructura del dataframe
df_colegios_bogota.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5073 entries, 0 to 5072
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   COD_LOCALIDAD  5073 non-null   int64
#  1   NOM_LOCALIDAD  5073 non-null   object
#  2   NOM_COLEGIO    5073 non-null   object
#  3   NOM_SEDE       5073 non-null   object
#  4   COD_DANE_TXT   5073 non-null   object
#  5   COD_DANE       5073 non-null   int64
#  6   CLASE          5073 non-null   object
#  7   JORNADA        5073 non-null   object
# dtypes: int64(2), object(6)
# memory usage: 317.2+ KB

# %%
# Creación de la coleccion icfes_colegios_bogota
db.drop_collection("icfes_colegios_bogota")
icfes_colegios_bogota  = create_collection("icfes_colegios_bogota", db)
load_collection(df_colegios_bogota.loc[df_colegios_bogota['JORNADA'] == 'MAÑANA'], icfes_colegios_bogota, list(df_colegios_bogota.columns), db)
# Out:
# *** creating collection icfes_colegios_bogota
# done
# *** loading collection Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'icfes_db_mlds'), 'icfes_colegios_bogota')
# done

# %% [markdown]
# Sobre las colecciones se realiza creación de índices:

# %%
db.icfes_estudiante_colegio.create_index( { "ESTU_CONSECUTIVO": 1 } )
db.icfes_estudiante_colegio.create_index( { "COLE_COD_DANE_ESTABLECIMIENTO": 1 } )
db.icfes_estudiante_colegio.create_index( { "COLE_COD_DEPTO_UBICACION": 1 } )
#
db.icfes_estudiante_estudiante.create_index( { "ESTU_CONSECUTIVO": 1 } )
db.icfes_estudiante_estudiante.create_index( { "ESTU_COD_RESIDE_DEPTO": 1 } )
#
db.icfes_estudiante_familia.create_index( { "ESTU_CONSECUTIVO": 1 } )
#
db.icfes_colegios_bogota.create_index( { "COD_DANE": 1 } )
# Out:
# 'COD_DANE_1'

# %% [markdown]
# Finalmente, la estructura de la base de datos MongoDB se visualiza de la siguiente forma:
#
# <img src="https://drive.google.com/uc?export=view&id=1z2sSsAHg7ZGPriwCqVd8I5CkdytUVh6N" width="100%">
